# %% [markdown]
# #  Necesssary libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import sqrt

from lightgbm import LGBMRegressor

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

# %% [markdown]
# # Data

# %%
data_train = pd.read_csv('/content/train.csv')
data_test = pd.read_csv('/content/test.csv')

# %%
X = data_train.drop(['id', 'MedHouseVal'], axis=1)
y = data_train['MedHouseVal']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=45)

# %% [markdown]
# # Training dataset

# %%
lgbm = LGBMRegressor()

lgbm.fit(X_train, y_train)
lgbm_predictions = lgbm.predict(X_test)
mse_lgbm = mean_squared_error(y_test, lgbm_predictions)
rmse_lgbm = np.sqrt(mse_lgbm)

print("MSE LightGBM:", mse_lgbm)
print("MSE LightGBM:", rmse_lgbm)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002538 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 29709, number of used features: 8
# [LightGBM] [Info] Start training from score 2.077071
# MSE LightGBM: 0.31132178578218883
# MSE LightGBM: 0.5579621723577584

# %%
lgbm = LGBMRegressor()

def run_kfold(RFR):
    kf = KFold(n_splits=300)
    rmse_scores = []
    fold = 0

    for train_index, test_index in kf.split(X):
        fold += 1
        X_train, X_test = X.values[train_index], X.values[test_index]
        y_train, y_test = y.values[train_index], y.values[test_index]

        lgbm.fit(X_train, y_train)
        lgbm_predictions = lgbm.predict(X_test)
        mse_lgbm = mean_squared_error(y_test, lgbm_predictions)
        rmse_lgbm = sqrt(mse_lgbm)

        rmse_scores.append(rmse_lgbm)
        print("Fold {0} accuracy: {1}".format(fold, rmse_lgbm))


    average_rmse = np.mean(rmse_scores)
    print(f'Average Mean Squared Error {average_rmse}')

run_kfold(lgbm)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003021 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079828
# Fold 1 accuracy: 0.5666604196915134
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002847 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080361
# Fold 2 accuracy: 0.4810384607874187
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002790 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079910
# Fold 3 accuracy: 0.48265671218737377
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001158 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080076
# Fold 4 accuracy: 0.49744848399546804
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002905 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080000
# Fold 5 accuracy: 0.5239271692534853
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002838 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079515
# Fold 6 accuracy: 0.5571035678495223
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002773 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080339
# Fold 7 accuracy: 0.5133772581949784
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002838 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079537
# Fold 8 accuracy: 0.5035119763731484
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003877 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079550
# Fold 9 accuracy: 0.6278975140051511
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002897 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079727
# Fold 10 accuracy: 0.49929201963161685
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002824 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079283
# Fold 11 accuracy: 0.553725295586684
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004248 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079310
# Fold 12 accuracy: 0.5198545080159268
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002898 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079715
# Fold 13 accuracy: 0.5200337641501378
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002924 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079697
# Fold 14 accuracy: 0.5369542480253828
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002892 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079733
# Fold 15 accuracy: 0.5445215100032025
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002842 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079772
# Fold 16 accuracy: 0.5035969576199246
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002803 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079775
# Fold 17 accuracy: 0.6106602484783828
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002959 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079020
# Fold 18 accuracy: 0.547170168851664
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002897 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079846
# Fold 19 accuracy: 0.5012263982113254
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002956 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079910
# Fold 20 accuracy: 0.5560194471315417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002806 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079971
# Fold 21 accuracy: 0.6435757196025702
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002805 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080089
# Fold 22 accuracy: 0.5003653946096954
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002846 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079596
# Fold 23 accuracy: 0.5850774016726794
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005189 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079675
# Fold 24 accuracy: 0.6138371726576088
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004860 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079783
# Fold 25 accuracy: 0.5465561829913519
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004596 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080032
# Fold 26 accuracy: 0.5803793417736306
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004738 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080414
# Fold 27 accuracy: 0.6455116149130218
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004560 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079645
# Fold 28 accuracy: 0.4773110348620082
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005152 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079751
# Fold 29 accuracy: 0.5896107973670166
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004939 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080153
# Fold 30 accuracy: 0.5942299231653948
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003048 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080351
# Fold 31 accuracy: 0.48437268958543145
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002782 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079484
# Fold 32 accuracy: 0.5854293522684606
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002813 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080237
# Fold 33 accuracy: 0.5013535023256106
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002808 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079407
# Fold 34 accuracy: 0.5716611656003234
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002860 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079494
# Fold 35 accuracy: 0.5629727826832464
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002787 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080048
# Fold 36 accuracy: 0.6224169952872295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002809 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080219
# Fold 37 accuracy: 0.608359736973135
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003119 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080313
# Fold 38 accuracy: 0.5205083429877347
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002881 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079850
# Fold 39 accuracy: 0.5744672388462854
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003229 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079176
# Fold 40 accuracy: 0.6872226127303126
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002872 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079357
# Fold 41 accuracy: 0.6063171538922423
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002806 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079596
# Fold 42 accuracy: 0.6037179718397497
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002817 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002816 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079306
# Fold 111 accuracy: 0.6252358766502004
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002938 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079683
# Fold 112 accuracy: 0.5662913667829371
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002789 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079821
# Fold 113 accuracy: 0.5105067495047019
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002919 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080166
# Fold 114 accuracy: 0.47150454857834434
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002849 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079908
# Fold 115 accuracy: 0.6163370538294232
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004745 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079121
# Fold 116 accuracy: 0.6137737992584507
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002880 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079196
# Fold 117 accuracy: 0.5610772157761108
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003488 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079169
# Fold 118 accuracy: 0.6587101384241179
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002840 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079788
# Fold 119 accuracy: 0.5567745062093763
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002794 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080073
# Fold 120 accuracy: 0.5366996907169034
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005338 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080079
# Fold 121 accuracy: 0.6621492687137922
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005512 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079842
# Fold 122 accuracy: 0.6222172103968978
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004762 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079858
# Fold 123 accuracy: 0.4622428582277773
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003588 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079590
# Fold 124 accuracy: 0.4936939189679556
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005892 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079443
# Fold 125 accuracy: 0.5999738844883605
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004664 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37013, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080000
# Fold 126 accuracy: 0.6063329009204802
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002801 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# ...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002914 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079475
# Fold 259 accuracy: 0.6313944225547068
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002985 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079293
# Fold 260 accuracy: 0.5670150711616516
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002786 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079556
# Fold 261 accuracy: 0.5522441072419889
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002831 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079648
# Fold 262 accuracy: 0.6030013256852658
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002884 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080239
# Fold 263 accuracy: 0.5877533456899263
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002884 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079733
# Fold 264 accuracy: 0.5611699833372252
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002782 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080035
# Fold 265 accuracy: 0.542289996843469
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002967 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080137
# Fold 266 accuracy: 0.582198339687259
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002838 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079476
# Fold 267 accuracy: 0.5560944780771963
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002868 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079915
# Fold 268 accuracy: 0.6135954953170829
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003280 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079591
# Fold 269 accuracy: 0.5519345180473869
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002898 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079902
# Fold 270 accuracy: 0.5906067141186304
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002892 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079591
# Fold 271 accuracy: 0.6176215984467286
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002931 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079961
# Fold 272 accuracy: 0.6333872412142796
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002856 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080124
# Fold 273 accuracy: 0.470343030109797
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002903 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079932
# Fold 274 accuracy: 0.5746208701006985
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002805 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079677
# Fold 275 accuracy: 0.5967161717589289
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002797 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080249
# Fold 276 accuracy: 0.5354460957439581
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002968 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079997
# Fold 277 accuracy: 0.6214789446790242
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002839 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079433
# Fold 278 accuracy: 0.6552617462948221
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005105 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079389
# Fold 279 accuracy: 0.5600495583040808
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002830 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079831
# Fold 280 accuracy: 0.5933204667587868
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002919 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079712
# Fold 281 accuracy: 0.6047657533159788
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004816 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079162
# Fold 282 accuracy: 0.6576684824931979
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004728 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079870
# Fold 283 accuracy: 0.5781853155402312
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004812 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079254
# Fold 284 accuracy: 0.6188623744974449
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005066 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080006
# Fold 285 accuracy: 0.5173042926230124
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004535 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079762
# Fold 286 accuracy: 0.6625546861701154
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009354 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079957
# Fold 287 accuracy: 0.636517641346265
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004583 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079972
# Fold 288 accuracy: 0.598131371275071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003722 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080165
# Fold 289 accuracy: 0.5939904692950464
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002852 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079566
# Fold 290 accuracy: 0.5632769245379787
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002828 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080036
# Fold 291 accuracy: 0.615880938432765
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002880 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079709
# Fold 292 accuracy: 0.5344072328176976
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002856 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079345
# Fold 293 accuracy: 0.5905914754192286
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003009 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080107
# Fold 294 accuracy: 0.520999672077444
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003156 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080011
# Fold 295 accuracy: 0.5972485221139517
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002889 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079578
# Fold 296 accuracy: 0.6468480595528051
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002948 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080201
# Fold 297 accuracy: 0.5371882692166883
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002929 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080125
# Fold 298 accuracy: 0.4673859587268349
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002820 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.079983
# Fold 299 accuracy: 0.6043809019300028
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002854 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1837
# [LightGBM] [Info] Number of data points in the train set: 37014, number of used features: 8
# [LightGBM] [Info] Start training from score 2.080004
# Fold 300 accuracy: 0.5030934844492719
# Average Mean Squared Error across 0.5649844268745763

# %%
ids = data_test['id']
predictions = lgbm.predict(data_test.drop(['id'], axis=1))

output = pd.DataFrame({'id' : ids, 'MedHouseVal': predictions})
output.to_csv('predictions.csv', index = False)
output.head()
# Out:
#       id  MedHouseVal
# 0  37137     0.708973
# 1  37138     1.009468
# 2  37139     3.998536
# 3  37140     3.409440
# 4  37141     2.494327
